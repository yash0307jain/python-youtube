# %% [markdown]
# ## Indentation

# %%
if True:
print("Hello")
# Out:
#   Cell In[1], line 2
#     print("Hello")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %%
if True:
    print("Hello")
# Out:
# Hello

# %%
if True:
    print("Hello")
    if True:
        print("World")

if True:
    print("Hello 2")

    if True:
        print("World 2")
# Out:
# Hello
# World
# Hello 2
# World 2

# %%
my_var1 = 10
    my_var2 = 20
# Out:
#   Cell In[4], line 2
#     my_var2 = 20
#     ^
# IndentationError: unexpected indent

# %%
my_var1 = 10
my_var2 = 20

# %%
my_var1 = 10

if True:
    my_var2 = 20

# %%
my_var1 = 10


def prf(var):
    var1 = 10
    return var


var1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 7
#       4     var1 = 10
#       5     return var
# ----> 7 var1
#
# NameError: name 'var1' is not defined

# %%
my_var1 = 10

if True:
    my_var3 = 20

print(my_var1)
print(my_var3)
# Out:
# 10
# 20

# %%
my_var1 = 10

if True:
    my_var1 = 20


print(my_var1)
# Out:
# 20

# %%
var = 11

if var == 10:
    var = 10
else:
    var = 20

print(var)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 8
#       5 else:
#       6     var3 = 20
# ----> 8 print(var22)
#       9 print(var3)
#
# NameError: name 'var22' is not defined
