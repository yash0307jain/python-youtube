# %% [markdown]
# ## Abstract Classes in Python
#
# -   An abstract class is a class that cannot be instantiated directly and is meant to be inherited by other classes.
# -   It defines abstract methods (declared but not implemented) that child classes must implement.

# %% [markdown]
# #### 1. Without Abstract Class

# %%
class Shape:
    def area(self):
        pass  # no enforcement for sub-classes


class Circle(Shape):
    pass  # forgot to define area()

# %%
shape = Shape()
print(shape.area())  # outputs None

circle = Circle()
print(circle.area())  # also outputs None — no real enforcement!
# Out:
# None
# None

# %% [markdown]
# ---
#
# #### 2. Introducing Abstract Classes with abc Module
#
# -   ABC → base class for defining abstract classes
# -   @abstractmethod → marks a method that must be implemented in subclasses

# %%
from abc import ABC, abstractmethod


class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

# %%
circle = Shape()  # ❌ TypeError: Can't instantiate abstract class
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 circle = Shape()  # ❌ TypeError: Can't instantiate abstract class
#
# TypeError: Can't instantiate abstract class Shape without an implementation for abstract method 'area'

# %% [markdown]
# ---
#
# #### 3. Implementing Abstract Methods in Subclass

# %%
from abc import ABC, abstractmethod
import math


class Shape(ABC):
    @abstractmethod
    def area(self):
        pass


class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * (self.radius**2)

# %%
circle = Circle(5)

print("Circle Area:", circle.area())
# Out:
# Circle Area: 78.53981633974483

# %%
class Rectangle(Shape):
    def __init__(self, width, height):
        self.width = width
        self.height = height

    def area(self) -> float:
        return self.width * self.height

# %%
rect = Rectangle(4, 6)

print("Rectangle Area:", rect.area())
# Out:
# Rectangle Area: 24

# %% [markdown]
# ---
#
# #### 4. Abstract Class with Both Abstract & Concrete Methods
#
# -   sound() → abstract (must be implemented)
# -   sleep() → concrete (already defined, usable directly)

# %%
from abc import ABC, abstractmethod


class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass

    def sleep(self):
        print("Sleeping... 😴")


class Dog(Animal):
    def sound(self):
        print("Bark 🐶")


dog = Dog()
dog.sound()
dog.sleep()
# Out:
# Bark 🐶
# Sleeping... 😴

# %% [markdown]
# ---
#
# #### 5. Abstract Class with Constructor

# %%
from abc import ABC, abstractmethod


class Vehicle(ABC):
    def __init__(self, brand):
        self.brand = brand

    @abstractmethod
    def start(self):
        pass


class Car(Vehicle):
    def start(self):
        print(f"The car {self.brand} is starting 🚗")


car = Car("Tesla")
car.start()
# Out:
# The car Tesla is starting 🚗

# %% [markdown]
# ---
#
# #### 6. Multiple Abstract Methods

# %%
from abc import ABC, abstractmethod


class Payment(ABC):
    @abstractmethod
    def pay(self, amount):
        pass

    @abstractmethod
    def show_balance(self):
        pass


class CreditCard(Payment):
    def __init__(self, balance):
        self.balance = balance

    def pay(self, amount):
        self.balance -= amount
        print(f"Paid ${amount}")

    def show_balance(self):
        print(f"Remaining balance: ${self.balance}")


obj = CreditCard(1000)
obj.pay(250)
obj.show_balance()
# Out:
# Paid $250
# Remaining balance: $750

# %% [markdown]
# ---
#
# #### 7. Abstract Class with Class Method and Static Method

# %%
from abc import ABC, abstractmethod


class Device(ABC):
    @abstractmethod
    def power_on(self):
        pass

    @staticmethod
    def company_name():
        print("Company: Python Tech Ltd.")


class Laptop(Device):
    def power_on(self):
        print("Laptop powering on... 💻")


Laptop.company_name()
laptop = Laptop()
laptop.power_on()
# Out:
# Company: Python Tech Ltd.
# Laptop powering on... 💻

# %% [markdown]
# ---
#
# #### 8. Abstract Properties

# %%
from abc import ABC, abstractmethod


class Student(ABC):

    @property
    @abstractmethod
    def name(self):
        pass


class SchoolStudent(Student):
    def __init__(self, name):
        self._name = name  # protected

    @property
    def name(self):
        return self._name


stud = SchoolStudent("Yash")
print("Student Name:", stud.name)
# Out:
# Student Name: Yash

# %% [markdown]
# ---
#
# #### 9. Payment Gateway Example

# %%
from abc import ABC, abstractmethod


class PaymentGateway(ABC):
    @abstractmethod
    def make_payment(self, amount):
        pass

    def connect(self):
        print("Connecting to payment server...")


class PayPal(PaymentGateway):
    def make_payment(self, amount):
        self.connect()
        print(f"Payment of ${amount} done using PayPal ✅")


class Stripe(PaymentGateway):
    def make_payment(self, amount):
        self.connect()
        print(f"Payment of ${amount} done using Stripe ✅")


# Using subclasses
paypal = PayPal()
stripe = Stripe()

paypal.make_payment(100)
stripe.make_payment(200)
# Out:
# Connecting to payment server...
# Payment of $100 done using PayPal ✅
# Connecting to payment server...
# Payment of $200 done using Stripe ✅
